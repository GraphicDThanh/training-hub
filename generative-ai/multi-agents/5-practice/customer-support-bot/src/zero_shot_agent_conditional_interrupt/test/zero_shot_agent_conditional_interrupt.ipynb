# %% [markdown]
# # Zero-shot Agent with Conditional Interrupt

# %%
# allow import
import sys
sys.path.append('../..')
from IPython.display import Image, display
from zero_shot_agent_conditional_interrupt.graph import graph

try:
    display(Image(graph.get_graph(xray=True).draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass
